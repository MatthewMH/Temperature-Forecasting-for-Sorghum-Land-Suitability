# %%
import pandas as pd

# %%
kecamatan = pd.read_csv('kecamatan.csv')

# %%
kecamatan
# Out:
#     gid  kdppum          namobj                               remark  kdpbps  \
# 0    31     NaN      Banjarsari  Wilayah Administrasi Keluruhan/Desa     NaN
# 1   157     NaN         Cibodas  Wilayah Administrasi Keluruhan/Desa     NaN
# 2   233     NaN        Cileuksa  Wilayah Administrasi Keluruhan/Desa     NaN
# 3   232     NaN        Cilengsi  Wilayah Administrasi Keluruhan/Desa     NaN
# 4    36     NaN      Bantarjati  Wilayah Administrasi Keluruhan/Desa     NaN
# 5     4     NaN        Antajaya  Wilayah Administrasi Keluruhan/Desa     NaN
# 6   259     NaN          Ciomas  Wilayah Administrasi Keluruhan/Desa     NaN
# 7   129     NaN         Cibadak  Wilayah Administrasi Keluruhan/Desa     NaN
# 8   313     NaN       Citeureup  Wilayah Administrasi Keluruhan/Desa     NaN
# 9    18     NaN    Babakanraden  Wilayah Administrasi Keluruhan/Desa     NaN
# 10   19     NaN   Babakansadeng  Wilayah Administrasi Keluruhan/Desa     NaN
# ...

# %%
koordinat_kecamatan = kecamatan[['wadmkc', 'xcoord', 'ycoord']]

# %%
koordinat_kecamatan.to_csv('koordinat_kecamatan.csv', index = False)
